# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
salaries_df = pd.read_csv('Salaries.csv')

# %%
salaries_df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
salaries_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 148654 entries, 0 to 148653
# Data columns (total 13 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   Id                148654 non-null  int64
#  1   EmployeeName      148654 non-null  object
#  2   JobTitle          148654 non-null  object
#  3   BasePay           148045 non-null  float64
#  4   OvertimePay       148650 non-null  float64
#  5   OtherPay          148650 non-null  float64
#  6   Benefits          112491 non-null  float64
#  7   TotalPay          148654 non-null  float64
#  8   TotalPayBenefits  148654 non-null  float64
#  9   Year              148654 non-null  int64
#  10  Notes             0 non-null       float64
#  11  Agency            148654 non-null  object
#  12  Status            0 non-null       float64
# dtypes: float64(8), int64(2), object(3)
# memory usage: 14.7+ MB

# %%
salaries_df.describe()
# Out:
#                   Id        BasePay    OvertimePay       OtherPay  \
# count  148654.000000  148045.000000  148650.000000  148650.000000
# mean    74327.500000   66325.448841    5066.059886    3648.767297
# std     42912.857795   42764.635495   11454.380559    8056.601866
# min         1.000000    -166.010000      -0.010000   -7058.590000
# 25%     37164.250000   33588.200000       0.000000       0.000000
# 50%     74327.500000   65007.450000       0.000000     811.270000
# 75%    111490.750000   94691.050000    4658.175000    4236.065000
# max    148654.000000  319275.010000  245131.880000  400184.250000
#
#             Benefits       TotalPay  TotalPayBenefits           Year  Notes  \
# count  112491.000000  148654.000000     148654.000000  148654.000000    0.0
# mean    25007.893151   74768.321972      93692.554811    2012.522643    NaN
# std     15402.215858   50517.005274      62793.533483       1.117538    NaN
# ...

# %%
salaries_df.isnull().sum()
# Out:
# Id                       0
# EmployeeName             0
# JobTitle                 0
# BasePay                609
# OvertimePay              4
# OtherPay                 4
# Benefits             36163
# TotalPay                 0
# TotalPayBenefits         0
# Year                     0
# Notes               148654
# Agency                   0
# Status              148654
# dtype: int64

# %%
salaries_df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       NaN  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       NaN  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       NaN  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       NaN  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       NaN  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
salaries_df.fillna(value=0, inplace=True)

# %%
salaries_df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       0.0  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       0.0  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       0.0  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       0.0  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       0.0  326373.19         326373.19
#
#    Year  Notes         Agency  Status
# ...

# %%
salaries_df.columns
# Out:
# Index(['Id', 'EmployeeName', 'JobTitle', 'BasePay', 'OvertimePay', 'OtherPay',
#        'Benefits', 'TotalPay', 'TotalPayBenefits', 'Year', 'Notes', 'Agency',
#        'Status'],
#       dtype='object')

# %%
salaries_df.BasePay
# Out:
# 0         167411.18
# 1         155966.02
# 2         212739.13
# 3          77916.00
# 4         134401.60
#             ...
# 148649         0.00
# 148650         0.00
# 148651         0.00
# 148652         0.00
# 148653         0.00
# Name: BasePay, Length: 148654, dtype: float64

# %%
salaries_df['BasePay']
# Out:
# 0         167411.18
# 1         155966.02
# 2         212739.13
# 3          77916.00
# 4         134401.60
#             ...
# 148649         0.00
# 148650         0.00
# 148651         0.00
# 148652         0.00
# 148653         0.00
# Name: BasePay, Length: 148654, dtype: float64

# %%
salaries_df.drop(['Notes','Status'], axis=1, inplace=True)

# %%
salaries_df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       0.0  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       0.0  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       0.0  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       0.0  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       0.0  326373.19         326373.19
#
#    Year         Agency
# 0  2011  San Francisco
# ...

# %%
salaries_df.shape
# Out:
# (148654, 11)

# %%
salaries_df[['BasePay', 'OvertimePay', 'OtherPay', 'Benefits', 'TotalPay', 'TotalPayBenefits']]
# Out:
#           BasePay  OvertimePay   OtherPay  Benefits   TotalPay  \
# 0       167411.18         0.00  400184.25       0.0  567595.43
# 1       155966.02    245131.88  137811.38       0.0  538909.28
# 2       212739.13    106088.18   16452.60       0.0  335279.91
# 3        77916.00     56120.71  198306.90       0.0  332343.61
# 4       134401.60      9737.00  182234.59       0.0  326373.19
# ...           ...          ...        ...       ...        ...
# 148649       0.00         0.00       0.00       0.0       0.00
# 148650       0.00         0.00       0.00       0.0       0.00
# 148651       0.00         0.00       0.00       0.0       0.00
# 148652       0.00         0.00       0.00       0.0       0.00
# 148653       0.00         0.00    -618.13       0.0    -618.13
#
#         TotalPayBenefits
# 0              567595.43
# 1              538909.28
# 2              335279.91
# 3              332343.61
# 4              326373.19
# ...                  ...
# ...

# %%
data1 = salaries_df['BasePay']+salaries_df['OvertimePay']+salaries_df['OtherPay']+salaries_df['Benefits']

# %%
salaries_df['New'] = data1

# %%
salaries_df.head()
# Out:
#    Id       EmployeeName                                        JobTitle  \
# 0   1     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1   2       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2   3     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3   4  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4   5    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       0.0  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       0.0  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       0.0  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       0.0  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       0.0  326373.19         326373.19
#
#    Year         Agency        New
# 0  2011  San Francisco  567595.43
# ...

# %%
salaries_df.drop(['Id'], axis=1, inplace=True)

# %%
col = list(salaries_df.columns)

# %%
col
# Out:
# ['EmployeeName',
#  'JobTitle',
#  'BasePay',
#  'OvertimePay',
#  'OtherPay',
#  'Benefits',
#  'TotalPay',
#  'TotalPayBenefits',
#  'Year',
#  'Agency',
#  'New']

# %%
salaries_df['Total'] = salaries_df.iloc[:,2:5].sum(axis=1)

# %%
salaries_df.head()
# Out:
#         EmployeeName                                        JobTitle  \
# 0     NATHANIEL FORD  GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# 1       GARY JIMENEZ                 CAPTAIN III (POLICE DEPARTMENT)
# 2     ALBERT PARDINI                 CAPTAIN III (POLICE DEPARTMENT)
# 3  CHRISTOPHER CHONG            WIRE ROPE CABLE MAINTENANCE MECHANIC
# 4    PATRICK GARDNER    DEPUTY CHIEF OF DEPARTMENT,(FIRE DEPARTMENT)
#
#      BasePay  OvertimePay   OtherPay  Benefits   TotalPay  TotalPayBenefits  \
# 0  167411.18         0.00  400184.25       0.0  567595.43         567595.43
# 1  155966.02    245131.88  137811.38       0.0  538909.28         538909.28
# 2  212739.13    106088.18   16452.60       0.0  335279.91         335279.91
# 3   77916.00     56120.71  198306.90       0.0  332343.61         332343.61
# 4  134401.60      9737.00  182234.59       0.0  326373.19         326373.19
#
#    Year         Agency        New  Total
# 0  2011  San Francisco  567595.43    NaN
# ...

# %%
salaries_df.iloc[0]
# Out:
# EmployeeName                                        NATHANIEL FORD
# JobTitle            GENERAL MANAGER-METROPOLITAN TRANSIT AUTHORITY
# BasePay                                                  167411.18
# OvertimePay                                                    0.0
# OtherPay                                                 400184.25
# Benefits                                                       0.0
# TotalPay                                                 567595.43
# TotalPayBenefits                                         567595.43
# Year                                                          2011
# Agency                                               San Francisco
# New                                                      567595.43
# Total                                                    567595.43
# Name: 0, dtype: object

# %%
salaries_df['EmployeeName']
# Out:
# 0            NATHANIEL FORD
# 1              GARY JIMENEZ
# 2            ALBERT PARDINI
# 3         CHRISTOPHER CHONG
# 4           PATRICK GARDNER
#                 ...
# 148649        Roy I Tillery
# 148650         Not provided
# 148651         Not provided
# 148652         Not provided
# 148653            Joe Lopez
# Name: EmployeeName, Length: 148654, dtype: object

# %%
for idx, row in salaries_df.iterrows():
    print(row['EmployeeName'])
# Out:
# NATHANIEL FORD
# GARY JIMENEZ
# ALBERT PARDINI
# CHRISTOPHER CHONG
# PATRICK GARDNER
# DAVID SULLIVAN
# ALSON LEE
# DAVID KUSHNER
# MICHAEL MORRIS
# JOANNE HAYES-WHITE
# ARTHUR KENNEY
# PATRICIA JACKSON
# EDWARD HARRINGTON
# JOHN MARTIN
# DAVID FRANKLIN
# RICHARD CORRIEA
# AMY HART
# SEBASTIAN WONG
# MARTY ROSS
# ELLEN MOFFATT
# VENUS AZAR
# JUDY MELINEK
# GEORGE GARCIA
# VICTOR WYRSCH
# JOSEPH DRISCOLL
# GREGORY SUHR
# JOHN HANLEY
# RAYMOND GUZMAN
# DENISE SCHMITT
# MONICA FIELDS
# HARLAN KELLY-JR
# DAVID SHINN
# GARY AMELIO
# JOHN TURSI
# JOSE VELO
# KHOA TRINH
# SUSAN CURRIN
# JAMES BOSCH
# JONES WONG
# BRENDAN WARD
# MICHAEL THOMPSON
# THOMAS ABBOTT
# THOMAS SIRAGUSA
# MICHAEL THOMPSON
# SHARON MCCOLE WICHER
# EDWIN LEE
# BRYAN RUBENSTEIN
# TRENT RHORER
# JAMES DUDLEY
# KEN YEE
# KIRK RICHARDSON
# BARBARA GARCIA
# MICHAEL ROLOVICH
# DARRYL HUNTER
# RAY CRAWFORD
# KEVIN CASHMAN
# BENJAMIN ROSENFIELD
# MARK KEARNEY
# DOUGLAS RIBA
# AI-KYUNG CHUNG
# KENNETH SMITH
# ANNA BROWN
# ...
